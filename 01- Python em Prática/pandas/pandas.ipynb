# %% [markdown]
# **Pandas:**

# %%
# Importando o pandas
import pandas as pd
# Carrega o arquivo para o dataframe pandas
dados = pd.read_csv("Credit.csv")
# Formato
dados.shape # Imprimiu dizendo que são 1000 linhas e 21 colunas
# Out:
# (1000, 21)

# %%
# Resumo estatisticos de colunas numericas 
dados.describe()
# Out:
#           duration  credit_amount  installment_commitment  residence_since  \
# count  1000.000000    1000.000000             1000.000000      1000.000000
# mean     20.903000    3271.258000                2.973000         2.845000
# std      12.058814    2822.736876                1.118715         1.103718
# min       4.000000     250.000000                1.000000         1.000000
# 25%      12.000000    1365.500000                2.000000         2.000000
# 50%      18.000000    2319.500000                3.000000         3.000000
# 75%      24.000000    3972.250000                4.000000         4.000000
# max      72.000000   18424.000000                4.000000         4.000000
#
#                age  existing_credits  num_dependents
# count  1000.000000       1000.000000     1000.000000
# mean     35.546000          1.407000        1.155000
# std      11.375469          0.577654        0.362086
# min      19.000000          1.000000        1.000000
# ...

# %%
# Mostra os primeiros registros
dados.head()
# se eu colocar qualquer parametro vai ser imprimido exemplo se eu colocar 5 vai imprimir os 2 primeiras linhas
# Out:
#   checking_status  duration                    credit_history   purpose  \
# 0              <0         6  'critical/other existing credit'  radio/tv
# 1        0<=X<200        48                   'existing paid'  radio/tv
#
#    credit_amount      savings_status employment  installment_commitment  \
# 0           1169  'no known savings'        >=7                       4
# 1           5951                <100     1<=X<4                       2
#
#         personal_status other_parties  ...  property_magnitude age  \
# 0         'male single'          none  ...       'real estate'  67
# 1  'female div/dep/mar'          none  ...       'real estate'  22
#
#    other_payment_plans housing existing_credits      job num_dependents  \
# 0                 none     own                2  skilled              1
# 1                 none     own                1  skilled              1
#
#    own_telephone foreign_worker class
# 0            yes            yes  good
# ...

# %%
# Mostra os ultimos registros 
dados.tail()
# se eu colocar qualquer parametro vai ser imprimido exemplo se eu colocar 5 vai imprimir os 2 primeiras linhas
# Out:
#     checking_status  duration                    credit_history  \
# 995   'no checking'        12                   'existing paid'
# 996              <0        30                   'existing paid'
# 997   'no checking'        12                   'existing paid'
# 998              <0        45                   'existing paid'
# 999        0<=X<200        45  'critical/other existing credit'
#
#                  purpose  credit_amount savings_status  employment  \
# 995  furniture/equipment           1736           <100      4<=X<7
# 996           'used car'           3857           <100      1<=X<4
# 997             radio/tv            804           <100         >=7
# 998             radio/tv           1845           <100      1<=X<4
# 999           'used car'           4576     100<=X<500  unemployed
#
#      installment_commitment       personal_status other_parties  ...  \
# 995                       3  'female div/dep/mar'          none  ...
# ...

# %%
# Se eu quiser ver apenas uma coluna 
dados[["duration"]]
# Out:
#      duration
# 0           6
# 1          48
# 2          12
# 3          42
# 4          24
# ..        ...
# 995        12
# 996        30
# 997        12
# 998        45
# 999        45
#
# [1000 rows x 1 columns]

# %%
# Filtrar linhas por índice 
dados.loc[900:905]
# Out:
#     checking_status  duration                    credit_history     purpose  \
# 900              <0        16  'critical/other existing credit'   'new car'
# 901   'no checking'        20  'critical/other existing credit'   'new car'
# 902   'no checking'        36  'critical/other existing credit'  'used car'
# 903   'no checking'        15                   'existing paid'    radio/tv
# 904   'no checking'        24                   'existing paid'    radio/tv
# 905              <0        12                   'existing paid'    radio/tv
#
#      credit_amount      savings_status employment  installment_commitment  \
# 900           2625                <100        >=7                       2
# 901           3485  'no known savings'         <1                       2
# 902          10477  'no known savings'        >=7                       2
# 903           1386  'no known savings'     1<=X<4                       4
# ...

# %%
# Linhas 1 e 3
dados.loc[[1,3]]
# Out:
#   checking_status  duration   credit_history              purpose  \
# 1        0<=X<200        48  'existing paid'             radio/tv
# 3              <0        42  'existing paid'  furniture/equipment
#
#    credit_amount savings_status employment  installment_commitment  \
# 1           5951           <100     1<=X<4                       2
# 3           7882           <100     4<=X<7                       2
#
#         personal_status other_parties  ...  property_magnitude age  \
# 1  'female div/dep/mar'          none  ...       'real estate'  22
# 3         'male single'     guarantor  ...    'life insurance'  45
#
#    other_payment_plans     housing existing_credits      job num_dependents  \
# 1                 none         own                1  skilled              1
# 3                 none  'for free'                1  skilled              2
#
#    own_telephone foreign_worker class
# 1           none            yes   bad
# 3           none            yes  good
#
# ...

# %%
# Filtro
dados.loc[dados["purpose"] == "radio/tv"]
# Out:
#     checking_status  duration                    credit_history   purpose  \
# 0                <0         6  'critical/other existing credit'  radio/tv
# 1          0<=X<200        48                   'existing paid'  radio/tv
# 8     'no checking'        12                   'existing paid'  radio/tv
# 12         0<=X<200        12                   'existing paid'  radio/tv
# 15               <0        24                   'existing paid'  radio/tv
# ..              ...       ...                               ...       ...
# 989        0<=X<200        24  'critical/other existing credit'  radio/tv
# 991   'no checking'        15                        'all paid'  radio/tv
# 992              <0        18                   'existing paid'  radio/tv
# 997   'no checking'        12                   'existing paid'  radio/tv
# 998              <0        45                   'existing paid'  radio/tv
#
#      credit_amount      savings_status employment  installment_commitment  \
# ...

# %%
# Outra condição 
dados.loc[dados["credit_amount"] > 18000]
# Out:
#     checking_status  duration         credit_history purpose  credit_amount  \
# 915        0<=X<200        48  'no credits/all paid'   other          18424
#
#     savings_status employment  installment_commitment       personal_status  \
# 915           <100     1<=X<4                       1  'female div/dep/mar'
#
#     other_parties  ...  property_magnitude age  other_payment_plans housing  \
# 915          none  ...    'life insurance'  32                 bank     own
#
#     existing_credits                          job num_dependents  \
# 915                1  'high qualif/self emp/mgmt'              1
#
#      own_telephone foreign_worker class
# 915            yes             no   bad
#
# [1 rows x 21 columns]

# %%
# Atribuimos resultado a variavel, criando outro df
credito = dados.loc[dados["credit_amount"] > 18000]
print(credito)
# Out:
#     checking_status  duration         credit_history purpose  credit_amount  \
# 915        0<=X<200        48  'no credits/all paid'   other          18424
#
#     savings_status employment  installment_commitment       personal_status  \
# 915           <100     1<=X<4                       1  'female div/dep/mar'
#
#     other_parties  ...  property_magnitude age  other_payment_plans housing  \
# 915          none  ...    'life insurance'  32                 bank     own
#
#     existing_credits                          job num_dependents  \
# 915                1  'high qualif/self emp/mgmt'              1
#
#      own_telephone foreign_worker class
# 915            yes             no   bad
#
# [1 rows x 21 columns]

# %%
# Defnimos só algumas colunas
credito2 = dados[["checking_status", "duration"]].loc[dados["credit_amount"] > 18000]
print(credito2)
# Out:
#     checking_status  duration
# 915        0<=X<200        48

# %%
# Séries, Única coluna
# Pode ser criada atraves de listas,array numpy ou data frame
listas = pd.Series([1,5,6,7,8,9,100,200,300])
print(listas)
# Out:
# 0      1
# 1      5
# 2      6
# 3      7
# 4      8
# 5      9
# 6    100
# 7    200
# 8    300
# dtype: int64

# %%
# Serie apartir de um array do numpy
import numpy as np
series = np.array([1,5,20,30,40,4])
print(series)
print("----------------------------")
series2 = pd.Series(series)
print(series2)
# Out:
# [ 1  5 20 30 40  4]
# ----------------------------
# 0     1
# 1     5
# 2    20
# 3    30
# 4    40
# 5     4
# dtype: int32

# %%
# Serie a partir de um data frame
serie3 = dados["purpose"]
print(serie3)
type(serie3)
# Out:
# 0                 radio/tv
# 1                 radio/tv
# 2                education
# 3      furniture/equipment
# 4                'new car'
#               ...
# 995    furniture/equipment
# 996             'used car'
# 997               radio/tv
# 998               radio/tv
# 999             'used car'
# Name: purpose, Length: 1000, dtype: object
# pandas.core.series.Series

# %%
# Note a diferença, temos um dataframe 
serie4 = dados[["purpose"]]
type(serie4)
# Out:
# pandas.core.series.Series

# %%
# Renomear colunas
dados.rename(columns={"checking_status":"Status de Verificação","credit_history":"Histórico de Crédito", "duration":"Duração","purpose":"Propósito"})
# Out:
#     Status de Verificação  Duração              Histórico de Crédito  \
# 0                      <0        6  'critical/other existing credit'
# 1                0<=X<200       48                   'existing paid'
# 2           'no checking'       12  'critical/other existing credit'
# 3                      <0       42                   'existing paid'
# 4                      <0       24              'delayed previously'
# ..                    ...      ...                               ...
# 995         'no checking'       12                   'existing paid'
# 996                    <0       30                   'existing paid'
# 997         'no checking'       12                   'existing paid'
# 998                    <0       45                   'existing paid'
# 999              0<=X<200       45  'critical/other existing credit'
#
#                Propósito  credit_amount      savings_status  employment  \
# ...

# %%
# Porém a alteração não é persistida :
dados.head(1)
# Out:
#   checking_status  duration                    credit_history   purpose  \
# 0              <0         6  'critical/other existing credit'  radio/tv
#
#    credit_amount      savings_status employment  installment_commitment  \
# 0           1169  'no known savings'        >=7                       4
#
#   personal_status other_parties  ...  property_magnitude age  \
# 0   'male single'          none  ...       'real estate'  67
#
#    other_payment_plans housing existing_credits      job num_dependents  \
# 0                 none     own                2  skilled              1
#
#    own_telephone foreign_worker class
# 0            yes            yes  good
#
# [1 rows x 21 columns]

# %%
# Para as alterações de colunas persistir :
dados.rename(columns={"checking_status":"Status de Verificação","credit_history":"Histórico de Crédito", "duration":"Duração","purpose":"Propósito"}, inplace =True)

# %%
dados.head(1)
# Out:
#   Status de Verificação  Duração              Histórico de Crédito Propósito  \
# 0                    <0        6  'critical/other existing credit'  radio/tv
#
#    credit_amount      savings_status employment  installment_commitment  \
# 0           1169  'no known savings'        >=7                       4
#
#   personal_status other_parties  ...  property_magnitude age  \
# 0   'male single'          none  ...       'real estate'  67
#
#    other_payment_plans housing existing_credits      job num_dependents  \
# 0                 none     own                2  skilled              1
#
#    own_telephone foreign_worker class
# 0            yes            yes  good
#
# [1 rows x 21 columns]

# %%
# Excluir coluna :
dados.drop("credit_amount",axis=1, inplace=True)

# %%
dados.head(1)
# Out:
#   Status de Verificação  Duração              Histórico de Crédito Propósito  \
# 0                    <0        6  'critical/other existing credit'  radio/tv
#
#        savings_status employment  installment_commitment personal_status  \
# 0  'no known savings'        >=7                       4   'male single'
#
#   other_parties  residence_since property_magnitude  age other_payment_plans  \
# 0          none                4      'real estate'   67                none
#
#   housing  existing_credits      job  num_dependents own_telephone  \
# 0     own                 2  skilled               1           yes
#
#   foreign_worker class
# 0            yes  good

# %%
# Verificar dados nulos 
dados.isnull()
# Out:
#      Status de Verificação  Duração  Histórico de Crédito  Propósito  \
# 0                    False    False                 False      False
# 1                    False    False                 False      False
# 2                    False    False                 False      False
# 3                    False    False                 False      False
# 4                    False    False                 False      False
# ..                     ...      ...                   ...        ...
# 995                  False    False                 False      False
# 996                  False    False                 False      False
# 997                  False    False                 False      False
# 998                  False    False                 False      False
# 999                  False    False                 False      False
#
#      savings_status  employment  installment_commitment  personal_status  \
# ...

# %%
# Verificar dados nulos 
dados.isnull().sum()
# Out:
# Status de Verificação     0
# Duração                   0
# Histórico de Crédito      0
# Propósito                 0
# savings_status            0
# employment                0
# installment_commitment    0
# personal_status           0
# other_parties             0
# residence_since           0
# property_magnitude        0
# age                       0
# other_payment_plans       0
# housing                   0
# existing_credits          0
# job                       0
# num_dependents            0
# own_telephone             0
# foreign_worker            0
# class                     0
# dtype: int64

# %%
# Retirar dados com NaN
dados.dropna()
# Out:
#     Status de Verificação  Duração              Histórico de Crédito  \
# 0                      <0        6  'critical/other existing credit'
# 1                0<=X<200       48                   'existing paid'
# 2           'no checking'       12  'critical/other existing credit'
# 3                      <0       42                   'existing paid'
# 4                      <0       24              'delayed previously'
# ..                    ...      ...                               ...
# 995         'no checking'       12                   'existing paid'
# 996                    <0       30                   'existing paid'
# 997         'no checking'       12                   'existing paid'
# 998                    <0       45                   'existing paid'
# 999              0<=X<200       45  'critical/other existing credit'
#
#                Propósito      savings_status  employment  \
# 0               radio/tv  'no known savings'         >=7
# ...

# %%
# Preencher dados faltantes
dados["Duração"].fillna(0,inplace = True)
# Este comando procura por valores ausentes (NaN) na coluna "Duração" do DataFrame 'dados'
# e substitui esses valores por 0.

# %%
# iloc
dados.iloc[0:3,0:5]
# Imprimiu as linhas de 0 a 3 e as colunas de 0 a 5
# Out:
#   Status de Verificação  Duração              Histórico de Crédito  Propósito  \
# 0                    <0        6  'critical/other existing credit'   radio/tv
# 1              0<=X<200       48                   'existing paid'   radio/tv
# 2         'no checking'       12  'critical/other existing credit'  education
#
#        savings_status
# 0  'no known savings'
# 1                <100
# 2                <100

# %%
dados.iloc[[1,2,3,7],0:8]
# Vai imprimiir as linhas 1,2,3,7 e a coluna de 0 a 8
# Out:
#   Status de Verificação  Duração              Histórico de Crédito  \
# 1              0<=X<200       48                   'existing paid'
# 2         'no checking'       12  'critical/other existing credit'
# 3                    <0       42                   'existing paid'
# 7              0<=X<200       36                   'existing paid'
#
#              Propósito savings_status employment  installment_commitment  \
# 1             radio/tv           <100     1<=X<4                       2
# 2            education           <100     4<=X<7                       2
# 3  furniture/equipment           <100     4<=X<7                       2
# 7           'used car'           <100     1<=X<4                       2
#
#         personal_status
# 1  'female div/dep/mar'
# 2         'male single'
# 3         'male single'
# 7         'male single'
